# %%
from datetime import datetime
save_index = str('x'+datetime.now().strftime("%m%d%y-%H%M%S"))

import os
os.mkdir(save_index)

# %%
DECODER_DIMS = {"text": 400, "logo": 400, "bp": 400, "indus": 400}
ENCODER_DIMS = {"full": 400, "res": 50, "mgr": 200, "design": 200}
K = 20

FOLDS = 4
BATCHES = 5000
ITERS = 10

ADAM_LR = 1e-5
MIN_AF = 1e-6
ANNEALING_BATCHES = 4000
NUM_PARTICLES = 1

CENTER_BP = True

DISABLE_TQDM = False

WEIGHT_DECAY = 0.

# %%
import sys
sys.path.insert(1, '../')

import os

import numpy as np
import torch
import torchvision.datasets as dset
import torch.nn as nn
import torchvision.transforms as transforms

import pyro
import pyro.distributions as dist
import pyro.contrib.examples.util  # patches torchvision
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam
from pyro import poutine

pyro.set_rng_seed(42)

import random
random.seed(42)

import pandas as pd

from skimage import io
from sklearn import metrics
from matplotlib import pyplot as plt

from tqdm.auto import tqdm, trange

from sklearn.metrics import classification_report

from data import SplitData
from model import LogoMVAE

assert pyro.__version__.startswith('1.3.0')

from IPython.display import clear_output
import time
from IPython import display

# %% [markdown]
# # Helper functions:

# %%
def split(a, n):
    k, m = divmod(len(a), n)
    return (a[i * k + min(i, m):(i + 1) * k + min(i + 1, m)] for i in range(n))

def compute_distance(z):
    b = z.reshape(z.shape[0], 1, z.shape[1])
    return np.sqrt(np.einsum('ijk, ijk->ij', z-b, z-b))

# %% [markdown]
# # Data Loading
#
# First, load text data, and apply word filter. Note on notation: `tx` stands for "true x," because the model variables are also called x.

# %%
textdf = pd.read_csv("../../../data/web_dtfm20_binary.csv", index_col=0)
tx_text = textdf.values
seltext = tx_text.sum(0) > 0.05
tx_text = textdf.values[:,seltext]

gt20words = tx_text.sum(1) > 20
tx_text = tx_text[gt20words,:]

words = textdf.columns[seltext]
N, V = tx_text.shape

binfeats = pd.read_csv("../../../data/y_bin_all_py2.csv", index_col=0)
tx_b = binfeats.values
tx_b = tx_b[gt20words,:]
M_b = tx_b.shape[1]

catfeats = pd.read_csv("../../../data/y_mult_ncolors_py2.csv", index_col=0)

tx_c1 = catfeats.values[:,0][gt20words]
M_c1 = len(np.unique(tx_c1))
tx_c1 = np.expand_dims(tx_c1, 1)

tx_c2 = catfeats.values[:,1][gt20words]
M_c2 = len(np.unique(tx_c2))
tx_c2 = np.expand_dims(tx_c2, 1)

tx_c3 = catfeats.values[:,2][gt20words]
M_c3 = len(np.unique(tx_c3))
tx_c3 = np.expand_dims(tx_c3, 1)

tx_c4 = catfeats.values[:,3][gt20words]
M_c4 = len(np.unique(tx_c4))
tx_c4 = np.expand_dims(tx_c4, 1)

tx_c5 = catfeats.values[:,4][gt20words]
M_c5 = len(np.unique(tx_c5))
tx_c5 = np.expand_dims(tx_c5, 1)

c1_labels = np.array(["black","blue_dark","blue_light","blue_medium","brown","green_dark",
                      "green_light","grey_dark","grey_light","orange","red","red_dark",
                      "yellow"])

c2_labels = np.array(["circle","rect-oval_medium","rect-oval_large","rect-oval_thin",
                      "square","triangle"])

c3_labels = np.array(["bad_letters","bulky_hollow_geometric","circular","dense_simple_geom",
                      "detailed_circle","hollow_circle","detailed_hor","long_hor","no_mark",
                      "simple","square","thin_vert_rect","vert_narrow","detailed","thin",
                      "hor_wispy"])

c4_labels = np.array(["nochars","sans","serif"])

c5_labels = np.array(["one_color","two_colors","three_colors","many_colors"])

bp = pd.read_csv("../../../data/bp_avg_all_traits.csv", index_col=0)

bp_labels = bp.columns

tx_bp = bp.values
tx_bp = tx_bp[gt20words]
if CENTER_BP:
    tx_bp = (tx_bp - tx_bp.mean(0)) / tx_bp.std(0)
M_bp = tx_bp.shape[1]

indus = pd.read_csv("../../../data/industry_codes_b2bc.csv", index_col=0)
indus = indus.iloc[np.in1d(indus.index, bp.index),:]
indus = indus.sort_index()

tx_indus = indus.values.astype('int')
tx_indus = tx_indus[:, tx_indus.sum(0) > 9]
tx_indus = tx_indus[gt20words,:]
M_indus = tx_indus.shape[1]

indus_labels = indus.columns[indus.values.sum(0) > 9]

allnames = binfeats.index.values[gt20words]

x_sizes = {"text": V, 
           "bin": M_b, 
           "cat1": M_c1, 
           "cat2": M_c2, 
           "cat3": M_c3, 
           "cat4": M_c4, 
           "cat5": M_c5, 
           "bp": M_bp, 
           "indus": M_indus, 
           "logo": M_b + M_c1 + M_c2 + M_c3 + M_c4 + M_c5, 
           "all": V + M_b + M_c1 + M_c2 + M_c3 + M_c4 + M_c5 + M_bp + M_indus}

task_sizes = {"full": x_sizes["all"], 
              "res": x_sizes["logo"] + x_sizes["indus"], 
              "design": x_sizes["text"] + x_sizes["bp"] + x_sizes["indus"], 
              "mgr": x_sizes["all"] - x_sizes["bp"]}

noptions = np.array([M_c1, M_c2, M_c3, M_c4, M_c5])

# %% [markdown]
# # Training: Instantiate Model and Run

# %%
givens = pd.DataFrame(np.concatenate(([[K], list(DECODER_DIMS.values()), list(ENCODER_DIMS.values()), [BATCHES], [ITERS], [ADAM_LR], [ANNEALING_BATCHES], [NUM_PARTICLES], [CENTER_BP], [WEIGHT_DECAY], [FOLDS]]))).T
givens.columns = ["K", "text_dec", "logo_dec", "bp_dec", "indus_dec", "full_enc", "res_enc", "mgr_enc", "des_enc", "batches", "iters", "adam_lr", "annealing_batches", "num_particles", "center_bp", "weight_decay","folds"]

# %% [markdown]
# Create holdout and cross-validation subsets (just the indices):

# %%
if FOLDS > 1:
    holdout_indices = list(split(np.arange(N), FOLDS))
    holdout_indices.append(np.array([]))
    fold_indices = [np.setdiff1d(np.arange(N), holdout_indices[i]) for i in range(FOLDS)]
    fold_indices.append(np.arange(N))
else:
    holdout_indices = [np.array([])]

# %% [markdown]
# Set the KL annealing schedule (same across each fold):

# %%
schedule = np.linspace(MIN_AF, 1., ANNEALING_BATCHES)
# schedule = np.concatenate([np.linspace(MIN_AF, 1., round(ANNEALING_BATCHES/4.)) for _ in range(4)])

# %%
track_everything = dict()

# %%
# Run the model across all folds (sequentially):

fold = FOLDS

for trial in tqdm(range(20)):
    track_z = dict()
    track_neighbors = dict()
    track_names = dict()

    for scale_zero in ["text","logo","bp","indus","full","full2"]:

        domain_scaling = {"text": 1., 
                          "logo": 1., 
                          "bp": 1., 
                          "indus": 1.}

        if scale_zero is not "full" and scale_zero is not "full2":
            domain_scaling[scale_zero] = 1e-8

        pyro.clear_param_store()

        data = SplitData(tx_text, tx_b, tx_c1, tx_c2, tx_c3, tx_c4, tx_c5, tx_bp, tx_indus, 
                         allnames, noptions, test_indices = holdout_indices[fold])   

        lmvae = LogoMVAE(K, ENCODER_DIMS, DECODER_DIMS, x_sizes, task_sizes, use_cuda = True, domain_scaling = domain_scaling)
        optimizer = Adam({"lr": ADAM_LR}) #, "weight_decay": 0.4})
        svi = SVI(lmvae.model, lmvae.guide, optimizer, loss=Trace_ELBO(num_particles = NUM_PARTICLES))

        for i in tqdm(range(BATCHES), desc="Batches", leave=False, disable=DISABLE_TQDM):

            if i < ANNEALING_BATCHES:
                annealing_factor = schedule[i]
            else:
                annealing_factor = 1.

            data.training.shuffle()

            for j in tqdm(range(ITERS), desc="Iters", leave=False, disable=True):
                svi.step(data.training, annealing_factor)

        # Final save of stats
        lmvae.eval()

        lmvae.predict(data.training)

        z = lmvae.pred.z.z_loc.cpu().numpy()
        end_names = data.training.names
        # z_est = z_est[:,z_est.std(0) > 0.5]

        dist_z = compute_distance(z)

        test_firms = ['itw','harman-intl','lilly','goldman-sachs','21st-century-fox','facebook','gucci','old-navy','3m','actavis','mcdonalds', 'kfc']
        test_neighbors = [end_names[dist_z[np.where(end_names == test_firms[i])[0][0],:].argsort()][1:5] for i in range(len(test_firms))]
        test_dist = [np.sort(dist_z[np.where(end_names == test_firms[i])[0][0],:].round(2))[1:5] for i in range(len(test_firms))]
        formatted_neighbors = [", ".join(test_neighbors[i].tolist()) for i in range(len(test_neighbors))]

        neighbors_df = pd.DataFrame(test_neighbors)
        neighbors_df.index = test_firms
        neighbors_df.columns = np.arange(1,5)

        track_z[scale_zero] = z
        track_names[scale_zero] = end_names
        track_neighbors[scale_zero] = neighbors_df
        
    track_everything[trial] = {'z': track_z, 'neighbors': track_neighbors, 'names': track_names}
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=5000.0, style=ProgressStyle(description_wid…

# %%
import pickle

tracked_things = track_everything

with open("track_results_big.dat", "wb") as f:
    pickle.dump(tracked_things, f)

# %%
import pickle
infile = open("track_results_big.dat",'rb')
tracked_things = pickle.load(infile)
infile.close()

# %%
results = pd.DataFrame()

# %%
for s in range(20):
    full_z = tracked_things[s]['z']['full']
    dist_full = compute_distance(full_z)

    top10_full = np.array([np.argsort(dist_full[i])[1:11] for i in range(dist_full.shape[0])])
    top10_full_names = tracked_things[s]['names']['full'][top10_full]
    top10_full_names_ordered = top10_full_names[np.argsort(tracked_things[s]['names']['full'])]
    
    full2_z = tracked_things[s]['z']['full2']
    dist_full2 = compute_distance(full2_z)

    top10_full2 = np.array([np.argsort(dist_full2[i])[1:11] for i in range(dist_full2.shape[0])])
    top10_full2_names = tracked_things[s]['names']['full2'][top10_full]
    top10_full2_names_ordered = top10_full2_names[np.argsort(tracked_things[s]['names']['full2'])]

    no_logo_z = tracked_things[s]['z']['logo']
    dist_no_logo = compute_distance(no_logo_z)

    top10_no_logo = np.array([np.argsort(dist_no_logo[i])[1:11] for i in range(dist_no_logo.shape[0])])
    top10_no_logo_names = tracked_things[s]['names']['logo'][top10_no_logo]
    top10_no_logo_names_ordered = top10_no_logo_names[np.argsort(tracked_things[s]['names']['logo'])]

    no_text_z = tracked_things[s]['z']['text']
    dist_no_text = compute_distance(no_text_z)

    top10_no_text = np.array([np.argsort(dist_no_text[i])[1:11] for i in range(dist_no_text.shape[0])])
    top10_no_text_names = tracked_things[s]['names']['text'][top10_no_text]
    top10_no_text_names_ordered = top10_no_text_names[np.argsort(tracked_things[s]['names']['text'])]

    no_bp_z = tracked_things[s]['z']['bp']
    dist_no_bp = compute_distance(no_bp_z)

    top10_no_bp = np.array([np.argsort(dist_no_bp[i])[1:11] for i in range(dist_no_bp.shape[0])])
    top10_no_bp_names = tracked_things[s]['names']['bp'][top10_no_bp]
    top10_no_bp_names_ordered = top10_no_bp_names[np.argsort(tracked_things[s]['names']['bp'])]

    no_indus_z = tracked_things[s]['z']['indus']
    dist_no_indus = compute_distance(no_indus_z)

    top10_no_indus = np.array([np.argsort(dist_no_indus[i])[1:11] for i in range(dist_no_indus.shape[0])])
    top10_no_indus_names = tracked_things[s]['names']['indus'][top10_no_indus]
    top10_no_indus_names_ordered = top10_no_indus_names[np.argsort(tracked_things[s]['names']['indus'])]
    
    if s == 0:
        results = pd.DataFrame({'full2': np.array([np.isin(top10_full2_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full2.shape[0])]).sum(1).mean(),
                                'logo': np.array([np.isin(top10_no_logo_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full.shape[0])]).sum(1).mean(),
                                'text': np.array([np.isin(top10_no_text_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full.shape[0])]).sum(1).mean(),
                                'bp': np.array([np.isin(top10_no_bp_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full.shape[0])]).sum(1).mean(),
                                'indus': np.array([np.isin(top10_no_indus_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full.shape[0])]).sum(1).mean()},
                               index = [0])
    else:
        temp = pd.DataFrame({'full2': np.array([np.isin(top10_full2_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full2.shape[0])]).sum(1).mean(),
                             'logo': np.array([np.isin(top10_no_logo_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full.shape[0])]).sum(1).mean(),
                             'text': np.array([np.isin(top10_no_text_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full.shape[0])]).sum(1).mean(),
                             'bp': np.array([np.isin(top10_no_bp_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full.shape[0])]).sum(1).mean(),
                             'indus': np.array([np.isin(top10_no_indus_names_ordered[i], top10_full_names_ordered[i]) for i in range(dist_full.shape[0])]).sum(1).mean()},
                             index = [s])
        results = results.append(temp)

# %%
results
# Out:
#        full2      logo     text        bp     indus
# 0   0.140227  4.668555  2.72238  3.685552  5.847025
# 1   0.140227  4.668555  2.72238  3.685552  5.847025
# 2   0.140227  4.668555  2.72238  3.685552  5.847025
# 3   0.140227  4.668555  2.72238  3.685552  5.847025
# 4   0.140227  4.668555  2.72238  3.685552  5.847025
# 5   0.140227  4.668555  2.72238  3.685552  5.847025
# 6   0.140227  4.668555  2.72238  3.685552  5.847025
# 7   0.140227  4.668555  2.72238  3.685552  5.847025
# 8   0.140227  4.668555  2.72238  3.685552  5.847025
# 9   0.140227  4.668555  2.72238  3.685552  5.847025
# 10  0.140227  4.668555  2.72238  3.685552  5.847025
# 11  0.140227  4.668555  2.72238  3.685552  5.847025
# 12  0.140227  4.668555  2.72238  3.685552  5.847025
# 13  0.140227  4.668555  2.72238  3.685552  5.847025
# 14  0.140227  4.668555  2.72238  3.685552  5.847025
# 15  0.140227  4.668555  2.72238  3.685552  5.847025
# 16  0.140227  4.668555  2.72238  3.685552  5.847025
# 17  0.140227  4.668555  2.72238  3.685552  5.847025
# 18  0.140227  4.668555  2.72238  3.685552  5.847025
# 19  0.140227  4.668555  2.72238  3.685552  5.847025

# %%
tracked_things[1]
# Out:
# {'z': {'text': array([[-0.98406446, -1.3058614 ,  0.5451891 , ...,  0.76194596,
#            0.0218945 , -0.92350864],
#          [ 0.23579463,  0.31325474, -1.6017869 , ...,  0.44085103,
#            0.31370008,  0.89894575],
#          [-0.2747689 ,  0.1701757 ,  0.6431251 , ...,  0.13568465,
#            0.12741002,  1.7813652 ],
#          ...,
#          [ 0.74947035, -0.03597721,  1.924873  , ..., -0.8110901 ,
#           -1.2328434 , -0.9932321 ],
#          [-1.7213477 ,  0.14785708,  1.7714406 , ...,  0.75371766,
#           -0.66321766, -0.5214674 ],
#          [ 0.6025658 ,  0.02221411, -2.090066  , ..., -0.75964963,
#           -0.02249207,  1.3496554 ]], dtype=float32),
#   'logo': array([[-0.54542446, -1.0141017 ,  0.30068758, ..., -2.1954021 ,
#            1.5750016 , -2.1292183 ],
#          [-0.48202243, -1.0954057 ,  0.8479999 , ..., -2.1275017 ,
#            0.01437005,  0.51638556],
#          [ 0.5931289 ,  0.25300363, -0.46347943, ..., -0.02884687,
#           -0.21792991, -0.12029386],
#          ...,
#          [-0.01156573, -1.2760562 , -1.0679511 , ..., -0.9988992 ,
#           -2.5075643 , -1.5207849 ],
#          [-0.6199556 , -1.6063215 , -0.0080087 , ...,  0.6042712 ,
#            0.14276801,  0.01107895],
#          [ 0.65180826,  1.4474372 , -0.560996  , ..., -0.325822  ,
#           -1.9662437 ,  0.7428676 ]], dtype=float32),
#   'bp': array([[-1.5569365e-01,  2.9377444e+00,  1.0858212e+00, ...,
#            9.8633569e-01, -2.2867111e-02, -2.4077021e-02],
#          [ 2.5928936e+00,  1.3194999e+00, -1.4433701e+00, ...,
#           -2.0989281e-01, -6.4657581e-01, -1.4018315e+00],
#          [-7.3711145e-01, -8.6040802e-02,  4.6279928e-01, ...,
#           -2.6329681e-03, -2.0137966e-01, -5.3728837e-01],
#          ...,
#          [ 1.3761455e+00, -2.7681991e-01, -1.1502184e+00, ...,
#           -8.9957160e-01, -2.3381190e-01,  5.8185321e-01],
#          [ 2.0911851e+00, -3.0460677e-01,  4.8481101e-01, ...,
#            5.1359886e-01,  2.3763619e-01,  7.0926720e-01],
#          [ 6.3910270e-01,  1.3047651e+00, -9.4300693e-01, ...,
#            1.5936005e+00,  8.6089778e-01,  2.4203576e-02]], dtype=float32),
#   'indus': array([[-1.7582992 , -0.6204741 , -0.792773  , ..., -0.9064521 ,
#            0.8077859 , -0.36207384],
#          [-0.05585454,  1.0309395 , -1.2714878 , ...,  0.3194063 ,
#            0.48771515,  0.40833655],
#          [ 0.3609954 ,  0.4436878 , -2.3690605 , ...,  1.811311  ,
#            1.3705134 ,  0.42765114],
#          ...,
#          [ 0.5660774 ,  0.33434612, -0.52468604, ..., -0.32176387,
#            0.39533532, -0.064827  ],
#          [ 1.0874814 ,  1.303886  , -1.0764498 , ..., -0.33505797,
#           -2.2196283 ,  0.57117885],
#          [ 0.9271684 ,  0.5131523 , -0.02262306, ...,  0.15885155,
#            0.34483802, -1.5992776 ]], dtype=float32),
#   'full': array([[ 1.8397777 ,  1.3351398 ,  0.14725414, ..., -0.05871295,
#           -1.5634581 ,  0.35695326],
#          [ 0.30487052,  0.5945539 ,  0.37554324, ...,  2.7319632 ,
#            0.2888486 , -0.18747264],
#          [-0.21418679,  0.6990659 ,  0.8453272 , ...,  1.7233094 ,
#           -0.70046246,  0.72373825],
#          ...,
#          [ 1.5347286 ,  1.5178043 ,  0.95016795, ...,  1.7999665 ,
#           -0.50068253, -0.7051122 ],
#          [ 2.3813841 ,  0.19093549, -1.2805455 , ...,  0.51591957,
#           -2.5153728 , -0.21219105],
#          [-0.12951213, -1.0150362 , -1.4570503 , ..., -0.89081573,
#           -1.1199626 ,  0.23066065]], dtype=float32),
#   'full2': array([[ 1.3063849 ,  0.3651126 ,  0.9245607 , ..., -0.14803869,
#            1.6411331 ,  2.6850574 ],
#          [-0.76871   ,  0.17444472, -0.07162505, ..., -1.4434493 ,
#            3.1156175 , -1.020925  ],
#          [ 0.6370273 , -0.22881585, -0.17536604, ...,  0.7242596 ,
#            0.5576296 ,  0.05941957],
#          ...,
#          [ 1.699246  ,  0.34447354, -1.3531928 , ...,  2.6885216 ,
#           -1.1412339 , -1.2097349 ],
#          [ 0.71494055,  1.8796918 ,  1.5029349 , ...,  2.670937  ,
#            1.3777014 ,  0.718223  ],
#          [ 1.5010525 , -0.6401105 ,  2.0005217 , ..., -1.177842  ,
#            1.4965643 ,  0.1479284 ]], dtype=float32)},
#  'neighbors': {'text':                                                 1                    2  \
#   itw                                           csc        owens-corning
#   harman-intl       harman-international-industries             motorola
#   lilly                       eli-lilly-and-company     davita-healthcar
#   goldman-sachs                      charles-schwab     american-express
#   21st-century-fox                           united       tommy-hilfiger
#   facebook                                  twitter                 uber
#   gucci                                wynn-resorts                  mac
#   old-navy                                      gap  ross-dress-for-less
#   3m                        florida-power-and-light               apache
#   actavis                    ingredion-incorporated                yahoo
#   mcdonalds                             wells-fargo                kraft
#   kfc                                   food-4-less          minute-maid
#
#                                                3                         4
#   itw                                      alcoa                   praxair
#   harman-intl                             apache  thermo-fisher-scientific
#   lilly                                 johnsons                   colgate
#   goldman-sachs                              aig               wells-fargo
#   21st-century-fox                       allianz                   lincoln
#   facebook                                 apple                   samsung
#   gucci                                  cartier                      zara
#   old-navy                              skechers               whole-foods
#   3m                                         csc                    lenovo
#   actavis                                invesco             dish-networks
#   mcdonalds         reinsurance-group-of-america                     seiyu
#   kfc                                land-olakes                    hormel  ,
#   'logo':                                                 1  \
#   itw                                       textron
#   harman-intl       harman-international-industries
#   lilly                        simon-property-group
#   goldman-sachs                                 kkr
#   21st-century-fox                              cbs
#   facebook                                  twitter
#   gucci                                        dior
#   old-navy                                      gap
#   3m                          stanley-black--decker
#   actavis                                   aramark
#   mcdonalds          performance-food-group-company
#   kfc                                        subway
#
#                                                   2                         3  \
#   itw                              lear-corporation  dana-holding-corporation
#   harman-intl                      westrock-company                 panasonic
#   lilly                                    johnsons        markel-corporation
#   goldman-sachs     jones-lang-lasalle-incorporated  american-financial-group
#   21st-century-fox                              nbc          news-corporation
#   facebook                                     uber                    nvidia
#   gucci                                         mac                   cartier
#   old-navy                      ross-dress-for-less                     kohls
#   3m                                        seagate                        hp
#   actavis                                   praxair                     cigna
#   mcdonalds                                     upc                     heinz
#   kfc                                   burger-king                   folgers
#
#                                                   4
#   itw                           illinois-tool-works
#   harman-intl                                 wipro
#   lilly                   kimberlyclark-corporation
#   goldman-sachs     guardian-life-ins-co-of-america
#   21st-century-fox                         time-inc
#   facebook                                taco-bell
#   gucci                                calvin-klein
#   old-navy                                  walmart
#   3m                                          xerox
#   actavis                                     pepsi
#   mcdonalds                               supervalu
#   kfc                                     pizza-hut  ,
#   'bp':                                                      1  \
#   itw                                illinois-tool-works
#   harman-intl            harman-international-industries
#   lilly             first-american-financial-corporation
#   goldman-sachs                              emcor-group
#   21st-century-fox                 realogy-holdings-corp
#   facebook                                       twitter
#   gucci                                            prada
#   old-navy                                           gap
#   3m                                             carrier
#   actavis                         ingredion-incorporated
#   mcdonalds                                  hanesbrands
#   kfc                                              tyson
#
#                                            2                             3  \
#   itw               eastman-chemical-company  reinsurance-group-of-america
#   harman-intl                          intel                        garmin
#   lilly             state-farm-insurance-cos                   cintas-corp
#   goldman-sachs                     mckinsey                  state-street
#   21st-century-fox               iheartmedia           activision-blizzard
#   facebook                              uber           ch2m-hill-companies
#   gucci                                 dior                           mac
#   old-navy                           walmart                        target
#   3m                           owensillinois                         levis
#   actavis                            aramark                 owens-corning
#   mcdonalds                       yum-brands                          lego
#   kfc                            cabelas-inc                     pizza-hut
#
#                                       4
#   itw                     owens-corning
#   harman-intl       visteon-corporation
#   lilly                          hormel
#   goldman-sachs         cons-edison-inc
#   21st-century-fox                  cbs
#   facebook                       clorox
#   gucci                        pvh-corp
#   old-navy          ross-dress-for-less
#   3m                illinois-tool-works
#   actavis                 owensillinois
#   mcdonalds                     safeway
#   kfc                            target  ,
#   'indus':                                                 1                         2  \
#   itw                           illinois-tool-works             owens-corning
#   harman-intl       harman-international-industries  thermo-fisher-scientific
#   lilly                                    johnsons      simon-property-group
#   goldman-sachs                            mckinsey                       kkr
#   21st-century-fox                          xfinity               iheartmedia
#   facebook                                  twitter                      uber
#   gucci                                         mac                      dior
#   old-navy                                      gap                     kohls
#   3m                                  owensillinois                   carrier
#   actavis                    ingredion-incorporated                   praxair
#   mcdonalds                                 colgate                     heinz
#   kfc                                   burger-king                   folgers
#
#                                                   3  \
#   itw                      eastman-chemical-company
#   harman-intl                   visteon-corporation
#   lilly                                 cintas-corp
#   goldman-sachs     jones-lang-lasalle-incorporated
#   21st-century-fox                              cbs
#   facebook                               salesforce
#   gucci                                     cartier
#   old-navy                      ross-dress-for-less
#   3m                                             hp
#   actavis                avery-dennison-corporation
#   mcdonalds                             wells-fargo
#   kfc                                     pizza-hut
#
#                                                   4
#   itw                                           ppg
#   harman-intl                            abbvie-inc
#   lilly                       eli-lilly-and-company
#   goldman-sachs     guardian-life-ins-co-of-america
#   21st-century-fox  cablevision-systems-corporation
#   facebook                                     ebay
#   gucci                                calvin-klein
#   old-navy                                  walmart
#   3m                            illinois-tool-works
#   actavis                  coremark-holding-company
#   mcdonalds                                     qvc
#   kfc                                         tyson  ,
#   'full':                                                 1                      2  \
#   itw                      dana-holding-corporation    illinois-tool-works
#   harman-intl       harman-international-industries              accenture
#   lilly                                    johnsons  eli-lilly-and-company
#   goldman-sachs                            mckinsey                    kkr
#   21st-century-fox                 news-corporation            iheartmedia
#   facebook                                  twitter                   uber
#   gucci                                        dior                    mac
#   old-navy                                      gap                walmart
#   3m                                             hp                carrier
#   actavis                avery-dennison-corporation          owensillinois
#   mcdonalds                             wells-fargo                  heinz
#   kfc                                        subway            food-4-less
#
#                                                          3  \
#   itw                                        owens-corning
#   harman-intl                                        wipro
#   lilly               first-american-financial-corporation
#   goldman-sachs     old-republic-international-corporation
#   21st-century-fox                     united-technologies
#   facebook                                      salesforce
#   gucci                                       calvin-klein
#   old-navy                             ross-dress-for-less
#   3m                                              gillette
#   actavis                                         phillips
#   mcdonalds                                         sunoco
#   kfc                                          cabelas-inc
#
#                                                   4
#   itw                                       textron
#   harman-intl                   visteon-corporation
#   lilly                                 cintas-corp
#   goldman-sachs     jones-lang-lasalle-incorporated
#   21st-century-fox            realogy-holdings-corp
#   facebook                                     ebay
#   gucci                                     cartier
#   old-navy                                  staples
#   3m                                           ikea
#   actavis                                   praxair
#   mcdonalds                                   pepsi
#   kfc                                   minute-maid  ,
#   'full2':                                                 1                    2  \
#   itw                      eastman-chemical-company        owens-corning
#   harman-intl       harman-international-industries     johnson-controls
#   lilly                       eli-lilly-and-company             johnsons
#   goldman-sachs                                 kkr             mckinsey
#   21st-century-fox                          xfinity              directv
#   facebook                                  twitter                 uber
#   gucci                                     cartier                  mac
#   old-navy                                      gap  ross-dress-for-less
#   3m                                       gillette                   hp
#   actavis                                     cigna                pepsi
#   mcdonalds                                     qvc          wells-fargo
#   kfc                                        subway          cabelas-inc
#
#                                       3                            4
#   itw               illinois-tool-works  spirit-aerosystems-holdings
#   harman-intl       visteon-corporation                      danaher
#   lilly                            mars                      colgate
#   goldman-sachs                    hsbc                raymond-james
#   21st-century-fox     news-corporation                          cbs
#   facebook                    taco-bell                      youtube
#   gucci                            dior                 calvin-klein
#   old-navy                      walmart                       target
#   3m                              xerox                        alcoa
#   actavis                       praxair       ingredion-incorporated
#   mcdonalds                       heinz                    supervalu
#   kfc                           folgers                  food-4-less  },
#  'names': {'text': array(['ramada', 'fluor', 'sirius', 'heinz', 'dollar-general',
#          'ch-robinson', 'cablevision-systems-corporation', 'michaels',
#          'davita-healthcar', 'aes', 'clinique', 'family-dollar',
#          'lkq-corporation', 'deere--company', 'fox',
#          'archerdanielsmidland-company', 'burlington-stores', 'fastenal-co',
#          'landrover', 'laboratory-corp-of-america', 'hersheys', 'lilly',
#          'tech-data', 'actavis', 'performance-food-group-company',
#          'trinity-industries', 'quest-diagnostic', 'eli-lilly-and-company',
#          'firstenergy-corp', 'seiyu', 'baxalta-incorporated', 'amgen',
#          'xfinity', 'air-products--chemicals', 'lifepoint-health',
#          'calvin-klein', 'otis', 'macys', 'ugi-corporation', 'metlife',
#          'cst-brands', 'liberty-interactive-corporation', 'oral-b',
#          'spartannash-company', 'assurant', 'wec-energy-group', 'jabil',
#          'celgene', 'wynn-resorts', 'booz-allen-hamilton-holding-corp',
#          'windstream', 'dior', 'gilead-sciences', 'skechers',
#          'weyerhaeuser', 'st-jude-medical', 'molina-healthcare', 'johnsons',
#          'walmart', 'lee', 'cadillac', 'mercedes-benz',
#          'tata-consultancy-services', 'chipotle-mexican',
#          'travelcenters-of-america-llc', 'wipro',
#          'precision-castparts-corp', 'ciel', 'ross-dress-for-less',
#          'the-bank-of-new-york-mellon', 'akamai-technologies',
#          'hca-holdings', 'baker-hughes', 'emc2',
#          'ak-steel-holding-corporation', 'patterson-companies', 'united',
#          'lyondellbasell', 'petsmart', 'williams', 'santander',
#          'waste-management', 'welltower-inc', 'time-inc', 'prudential',
#          'yahoo', 'youtube', 'aramark', 'fanta', 'goodyear', 'directv',
#          'moodys', 'sempra-energy', 'general-motors', 'mt-bank', 'gatorade',
#          'kraft', 'kimberlyclark-corporation', 'caterpillar', 'hp',
#          'voya-financial', 'micron-technology', 'johnnie-walker', 'ebay',
#          'nordstrom', 'food-4-less', 'nrg-energy',
#          'telephone-and-data-systems', 'starbucks',
#          'starwood-hotels--resorts-worldwide', 'victorias-secret',
#          'whirlpool', 'ace', 'sandisk', 'delta', 'kenworth', 'ikea',
#          'crown-holdings-inc', 'mattel', 'invesco', 'tracfone',
#          'salesforce', 'mccormick', 'sealed-air-corporation',
#          'packaging-corporation-of-america', 'kohls', 'westrock-company',
#          'wesco-international', 'bank-of-america', 'cvs', 'lennar', 'esso',
#          'quaker-foods-and-snacks', 'timberland', 'illinois-tool-works',
#          'mcdonalds', 'hyundai', 'loews-corporation',
#          'teachers-insurance-and-annuity-association', 'airbnb',
#          'blackstone', 'bacardi', 'reinsurance-group-of-america',
#          'iron-mountain-inc', 'accenture', 'cintas-corp',
#          'group-1-automotive', 'nbc', 'hertz', 'freeport-mcmoran',
#          'dte-energy-co', 'toys-r-us', 'insight-enterprises', 'netapp',
#          'avery-dennison-corporation', 'cameron-international-corporation',
#          '3m', 'murphy-usa', 'suntrust', 'envision-healthcare-holdings',
#          'lam-research-corporation', 'blackrock', 'l-brands',
#          'jones-lang-lasalle-incorporated', 'mini', 'optumhealth',
#          'office-depot', 'gap', 'kfc', 'omnicom-group', 'siemens',
#          'emc-corporation', 'western-union',
#          'huntington-ingalls-industries', 'buick', 'chs', 'spectrum',
#          'unitedhealth', 'chevron', 'farmers-insurance-exchange',
#          'best-buy', 'tiffany-co', 'upc', 'lm', 'western-digital', 'hm',
#          'national-oilwell-varco', 'michael-kors', 'nissan',
#          'jetblue-airways-corporation', 'abbott-labs', 'electronic-arts',
#          'american-electric-power-company', 'chesterfield', 'regions',
#          'eog-resources', 'dicks-sporting', 'centerpoint-energy', 'hsbc',
#          'carmax', 'applied-materials', 'harris-corp', 'toyota',
#          'owens-corning', 'eastman-chemical-company', 'western-refining',
#          'citi', 'tesla', 'tyson', 'philadelphia-insurance-companies',
#          'twitter', 'snap-on-inc', 'l3-communications-holdings', 'pedigree',
#          'southern-company', 'owens-minor', 'kelloggs',
#          'boston-scientific-corp', 'safeway', 'sheraton',
#          'guardian-life-ins-co-of-america', 'microsoft', 'entergy',
#          'subway', 'abc', 'sundown', 'ryder-system', 'nestle',
#          'hp-enterprise', 'mars', 'ge', 'emerson', 'masco', 'ibm',
#          'oreilly-auto-parts', 'newell-brands', 'aecom-technology',
#          'amphenol-corporation', 'chase', 'avis-budget-group',
#          'halliburton', 'prada', 'under-armour', 'fossil',
#          'dana-holding-corporation', 'cisco', 'xerox',
#          'world-fuel-services-corporation', 'tjx', 'boeing', 'minute-maid',
#          'zara', 'arrow-electronics', 'barnes-noble', 'zimmer',
#          'marathon-petroleum', 'ch2m-hill-companies', 'whole-foods', 'visa',
#          'dominion', 'owensillinois', 'polaris-inds', 'nvidia',
#          'discovery-media', 'dell', 'washington-post',
#          'nationwide-mutual-insurance-co', 'international-paper',
#          'paccar-inc', 'edison-international', 'treehouse-foods',
#          'becton-dickinson-and-company', 'coca-cola',
#          'erie-insurance-group', 'ncr-corporation', 'markel-corporation',
#          'cincinnati-financial-corporation', 'sabre',
#          'massachusetts-mutual-life-insurance-company', 'att',
#          'charter-communications', 'flowers-foods', 'biogen-idec-inc',
#          'steel-dynamics', 'american-family-insurance-group', 'canon',
#          'moet', 'ameriprise-financial', 'fannie-mae', 'pultegroup',
#          'clorox', 'the-hartford', 'emcor-group', 'mosaic', 'devon',
#          'stryker', 'nextera-energy', 'cognizant', 'mountain-dew',
#          'sears-holdings-corporation', 'apple', 'grey-goose', 'walgreens',
#          'textron', 'first-data-corp', 'neutrogena', 'mohawk-industries',
#          'philip-morris', 'panasonic', 'dollar-tree', 'medtronic',
#          'constellation-brands', 'equinix',
#          'quintiles-transnational-holdings', 'alcoa', 'cinemark',
#          'raymond-james', 'cbi', 'kelly-services', 'raytheon',
#          'american-financial-group', 'colgate', 'agco-corporation',
#          'spectra-energy-corp', 'celanese-corporation', 'avnet',
#          'fiserv-inc', 'expedia', 'xpo-logistics', 'sunoco', 'dr-pepper',
#          'jp-morgan', 'sysco', 'camel', 'westin', 'hanesbrands', 'nike',
#          'du-pont', 'dow', 'frontier', 'facebook', 'garmin', 'alphabet',
#          'peabody-energy-corporation', 'lear-corporation',
#          'cardinal-health', 'autonation', 'ecolab-inc', 'dhl',
#          'burger-king', 'cabelas-inc', 'porsche', 'las-vegas-sands',
#          'the-north-face', 'hrg-group', 'yoplait', 'discover', 'wyndham',
#          'leucadia-national-corporation', 'audi', 'marriott', 'samsung',
#          'honeywell', 'lansing-trade-group', 'old-navy',
#          'mgm-resorts-international', 'hermes', 'mondelez-international',
#          'abbvie-inc', 'priceline', 'american-airlines', 'sprite',
#          'bristol-myers-squibb', 'reynolds-american', 'campbells', 'intel',
#          'univar', 'humana-inc', 'exelon', 'general-mills', 'verizon',
#          'carnival', 'qvc', 'courtyard', 'universal-music-group', 'loreal',
#          'target', 'valero', 'new-york-life-insurance-company',
#          'union-pacific', 'eversource-energy', 'travelers', 'coors',
#          'baxter-international', 'domtar-corporation', '21st-century-fox',
#          'penske-automotive-group', 'lego', 'american-express',
#          'thomson-reuters', 'cdw-corporation', 'cigna',
#          'hollyfrontier-corporation', 'ameren-corporation', 'chevrolet',
#          'comcast-corporation', 'xbox', 'royal-caribbean-cruises',
#          'goldman-sachs', 'pbf-energy', 'cme', 'activision-blizzard',
#          'rite-aid-corporation', 'ww-grainger-inc', 'centurylink',
#          'lockheed-martin', 'henry-schein-inc', 'panera-bread', 'broadcom',
#          'aetna', 'expeditors-international-of-washington', 'netflix',
#          'tenneco', 'newmont-mining-corporation', 'doubletree', 'allianz',
#          'sherwin-williams', 'kitchenaid', 'liberty-mutual-holding-company',
#          'delek-us-holdings', 'alaska-air-group', 'unum-group', 'sams-club',
#          'nielsen', 'borgwarner-inc',
#          'first-american-financial-corporation', 'hilton', 'csx', 'sap',
#          'bed-bath-and-beyond', 'cerner-corp', 'the-home-depot',
#          'xcel-energy-inc', 'pizza-hut', 'general-dynamics',
#          'anixter-international', 'intl-fcstone', 'mckesson',
#          'coremark-holding-company', 'quanta-services-inc',
#          'ppl-corporation', 'aig', 'energy-future-holdings-corp', 'workday',
#          'jack-in-the-box', 'synnex-corporation', 'navient-corporation',
#          'newport', 'dr-horton', 'morgan-stanley', 'bbt',
#          'calpine-corporation', 'republic-services',
#          'wellcare-health-plans', 'adobe', 'vmware', 'autozone', 'apache',
#          'hyatt', 'ngl-energy-partners-lp', 'iheartmedia', 'infosys',
#          'johnson-controls', 'kindred-healthcare', 'us-foods-holding-corp',
#          'taco-bell', 'john-hancock', 'tommy-hilfiger', 'merck',
#          'yum-brands', 'capital-one', 'land-olakes', 'pfizer', 'pseg',
#          'ups', 'tractor-supply', 'hormel', 'parker-hannifin', 'mac',
#          'altria-group', 'phillips', 'cbre', 'anthem',
#          'commercial-metals-company', 'jm-smucker', 'kia', 'danaher',
#          'volkswagen', 'sonic-automotive', 'anadarko', 'oneok',
#          'mutual-of-omaha-insurance-company', 'us-bank', 'eaton',
#          'qualcomm', 'budweiser', 'nisource', 'deloitte', 'airgas',
#          'dish-networks', 'cbs', 'southwest', 'adidas', 'p-and-g',
#          'duke-energy', 'arthur-j-gallagher--co', 'kinder-morgan',
#          'alliance-data-systems-corp', 'burberry', 'dean-foods-company',
#          'marshalls', 'veritiv-corp', 'tech-mahindra', 'corning',
#          'advance-auto-parts', 'pge', 'rr-donnelley-and-sons-co',
#          'florida-power-and-light', 'spirit-aerosystems-holdings',
#          'carrier', 'gmc', 'mckinsey', 'hbo', 'dominos-pizza',
#          'hyatt-regency', 'lenovo', 'terex-corporation', 'kkr',
#          'schlumberger', 'ralph-lauren', 'staples',
#          'thrivent-financial-for-lutherans', 'pnc', 'lincoln', 'gillette',
#          'espn', 'hd-supply', 'sun-america', 'targa-resources-corp',
#          'simon-property-group', 'levis', 'supervalu', 'monsanto-company',
#          'charles-schwab', 'tripadvisor', 'franklin-templeton-investments',
#          'seaboard-corporation', 'publix', 'folgers', 'fedex', 'heineken',
#          'fidelity-national', 'mtv', 'doritos-tortilla-chips',
#          'ally-financial', 'essendant', 'conocophillips',
#          'reliance-steel-aluminum-co', 'nucor-corporation',
#          'express-scripts', 'max-factor', 'pratt-and-whitney', 'costco',
#          'allergan', 'enterprise', 'community-health-systems',
#          'harman-international-industries', 'bcg', 'cadbury', 'purina',
#          'old-republic-international-corporation', 'coach', 'symantec',
#          'nvr', 'monster-beverage', 'cons-edison-inc', 'mobil', 'big-lots',
#          'disney', 'jb-hunt-transport-services', 'tenet-healthcare-corp',
#          'cartier', 'norfolk', 'amazon', 'bnsf-railway', 'harley-davidson',
#          'centene-corporation', 'stanley-black--decker',
#          'asbury-automotive-group', 'tesoro-corporation', 'maytag',
#          'johnson-johnson', 'abm', 'live-nation-entertainment',
#          'hcl-technologies', 'gamestop', 'warner-bros', 'lawson-software',
#          'mclane-company', 'rockwell-automation',
#          'autoowners-insurance-group', 'pitney-bowes-inc',
#          'global-partners-lp', 'host-hotels-and-resorts', 'progressive',
#          'fifth-third-bank', 'honda', 'aflac', 'conagra-foods',
#          'mastercard', 'ingredion-incorporated', 'black-and-decker',
#          'harman-intl', 'dillards', 'sony', 'gucci', 'wells-fargo',
#          'motorola', 'jc-penney', 'google', 'bmw',
#          'northwestern-mutual-life-insurance-company', 'parliament',
#          'chesapeake-energy-corporation', 'ppg', 'pacific-life',
#          'norwegian-cruise', 'estee-lauder', 'ingram-micro', 'ford',
#          'geico', 'state-farm-insurance-cos', 'exxonmobil', 'rackspace',
#          'csc', 'plains-gp-holdings', 'texas-instruments',
#          'huntsman-corporation', 'pepsi', 'chubb', 'autoliv',
#          'thermo-fisher-scientific', 'health-net-inc', 'hess',
#          'amerisourcebergen', 'vf-corporation', 'dover-corporation',
#          'graybar-electric-company', 'lithia-motors', 'allstate', 'avon',
#          'foot-locker', 'fmc-technologies', 'linkedin',
#          'oshkosh-corporation', 'praxair', 'realogy-holdings-corp',
#          'united-technologies', 'itw', 'cummins', 'seagate',
#          'darden-restaurants', 'news-corporation', 'bond-street', 'uber',
#          'kroger', 'tropicana-beverages', 'louis-vuitton', 'adp',
#          'holiday-inn', 'paramount', 'universal-health-services',
#          'cms-energy-corporation', 'principal-financial-group', 'booking',
#          'sanmina-corporation', 'occidental-petroleum-corporation',
#          'ball-corp', 'visteon-corporation', 'freddie-mac', 'teradata',
#          'caseys-general', 'energy-transfer-equity', 'jacobs-engineering',
#          'jarden-corporation', 'ulta-salon-cosmetics', 'ingersoll-rand',
#          'pvh-corp', 'paypal', 'citizens', 'ashland', 'state-street',
#          'lowes', 'danone', 'wrigleys', 'level-3'], dtype=object),
#   'logo': array(['dean-foods-company', 'davita-healthcar', 'fmc-technologies',
#          'cartier', 'oral-b', 'cameron-international-corporation', 'kfc',
#          'terex-corporation', 'charles-schwab', 'omnicom-group', 'hbo',
#          'autoliv', 'michaels', 'medtronic', 'reliance-steel-aluminum-co',
#          'quaker-foods-and-snacks', 'autoowners-insurance-group',
#          'halliburton', 'ikea', 'ford', 'louis-vuitton',
#          'starwood-hotels--resorts-worldwide', 'kelloggs',
#          'jetblue-airways-corporation', 'sap', 'ralph-lauren', 'paramount',
#          'wrigleys', 'spartannash-company', 'aecom-technology',
#          'leucadia-national-corporation', 'caterpillar', 'panera-bread',
#          'telephone-and-data-systems', 'maytag', 'mohawk-industries',
#          'otis', 'l-brands', 'pvh-corp', 'workday', 'walgreens', 'xerox',
#          'siemens', 'farmers-insurance-exchange', 'verizon',
#          'patterson-companies', 'mastercard', 'purina', 'pedigree',
#          'thermo-fisher-scientific', 'cms-energy-corporation',
#          'eastman-chemical-company', 'express-scripts', 'eaton', 'hormel',
#          'staples', 'lincoln', 'welltower-inc', 'mini', 'nvr',
#          'illinois-tool-works', 'santander', 'dell', 'general-motors',
#          'bnsf-railway', 'henry-schein-inc', 'itw', 'universal-music-group',
#          'peabody-energy-corporation', 'cardinal-health', 'voya-financial',
#          'nestle', 'textron', 'fluor', 'walmart', 'petsmart',
#          'john-hancock', 'firstenergy-corp', 'wells-fargo', 'eog-resources',
#          'ibm', '3m', 'lawson-software', 'masco', 'warner-bros',
#          'windstream', 'unum-group', 'ryder-system', 'schlumberger', 'cvs',
#          'old-republic-international-corporation', 'xcel-energy-inc',
#          'discovery-media', 'dana-holding-corporation', 'cigna',
#          'whirlpool', 'pratt-and-whitney', 'fossil', 'sony', 'doubletree',
#          'mac', 'international-paper', 'mt-bank', 'st-jude-medical',
#          'campbells', 'wellcare-health-plans', 'fifth-third-bank', 'att',
#          'hp', 'panasonic', 'lego', 'costco', 'macys', 'expedia',
#          'whole-foods', 'baxalta-incorporated', 'mckinsey',
#          'burlington-stores', 'edison-international', 'trinity-industries',
#          'celgene', 'alliance-data-systems-corp', 'hcl-technologies',
#          'suntrust', 'hsbc', 'mattel', 'emc-corporation', 'jabil',
#          'union-pacific', 'ngl-energy-partners-lp', 'cisco',
#          'sealed-air-corporation', 'visa', 'wyndham',
#          'penske-automotive-group', 'oneok', 'southern-company',
#          'ugi-corporation', 'coors', 'uber', 'laboratory-corp-of-america',
#          'budweiser', 'humana-inc', 'charter-communications',
#          'lockheed-martin', 'lenovo', 'sirius', 'gap', 'seiyu',
#          'michael-kors', 'infosys', 'state-street', 'baxter-international',
#          'food-4-less', 'comcast-corporation', 'qvc', 'xbox',
#          'ncr-corporation', 'level-3', 'sunoco', 'ch2m-hill-companies',
#          'spectra-energy-corp', 'state-farm-insurance-cos',
#          'centene-corporation', 'expeditors-international-of-washington',
#          'jb-hunt-transport-services', 'tesla', 'celanese-corporation',
#          'directv', 'mckesson', 'office-depot', 'yum-brands', 'nissan',
#          'kkr', 'navient-corporation', 'carmax', 'community-health-systems',
#          'jp-morgan', 'vf-corporation', 'netapp', 'geico',
#          'fidelity-national', 'xpo-logistics', 'pge',
#          'hollyfrontier-corporation', 'lowes', 'hilton', 'alphabet',
#          'du-pont', 'duke-energy', 'pfizer', 'dior', 'lansing-trade-group',
#          'capital-one', 'nordstrom', 'cinemark',
#          'sears-holdings-corporation', 'deere--company', 'mars', 'deloitte',
#          'dish-networks', 'eversource-energy', 'abbvie-inc',
#          'cons-edison-inc', 'booking', 'kinder-morgan', 'delta',
#          'occidental-petroleum-corporation', 'nrg-energy', 'garmin',
#          'micron-technology', 'fannie-mae', 'activision-blizzard',
#          'synnex-corporation', 'frontier', 'kohls', 'abbott-labs',
#          'cummins', 'harman-intl', 'lithia-motors',
#          'liberty-interactive-corporation', 'crown-holdings-inc', 'hm',
#          'entergy', 'netflix', 'coremark-holding-company',
#          'lkq-corporation', 'world-fuel-services-corporation', 'toyota',
#          'pnc', 'sempra-energy', 'ppg', 'general-mills', 'boeing',
#          'big-lots', 'norwegian-cruise', 'kelly-services', 'dow', 'fox',
#          'valero', 'spectrum', 'western-digital', 'jacobs-engineering',
#          'chubb', 'westrock-company', 'zimmer', 'goldman-sachs',
#          'burger-king', 'tech-mahindra', 'principal-financial-group',
#          'northwestern-mutual-life-insurance-company',
#          'chesapeake-energy-corporation', 'dhl', 'clinique', 'freddie-mac',
#          'travelcenters-of-america-llc', '21st-century-fox', 'baker-hughes',
#          'equinix', 'allstate', 'emcor-group', 'kindred-healthcare',
#          'sanmina-corporation', 'sabre', 'anixter-international', 'honda',
#          'dte-energy-co', 'hrg-group', 'franklin-templeton-investments',
#          'gmc', 'anthem', 'booz-allen-hamilton-holding-corp',
#          'packaging-corporation-of-america', 'aig', 'intl-fcstone',
#          'cincinnati-financial-corporation', 'hyatt', 'jc-penney',
#          'cadbury', 'rite-aid-corporation',
#          'quintiles-transnational-holdings', 'avnet', 'newell-brands',
#          'kroger', 'universal-health-services', 'us-bank', 'microsoft',
#          'coach', 'minute-maid', 'bond-street',
#          'philadelphia-insurance-companies', 'mosaic', 'travelers', 'pepsi',
#          'chase', 'taco-bell', 'tractor-supply', 'pseg',
#          'mutual-of-omaha-insurance-company', 'chevrolet', 'danone',
#          'canon', 'johnson-johnson', 'pizza-hut', 'nbc', 'cintas-corp',
#          'global-partners-lp', 'kenworth', 'ingersoll-rand',
#          'conagra-foods', 'jones-lang-lasalle-incorporated', 'praxair',
#          'hess', 'mclane-company', 'ups', 'dicks-sporting', 'paccar-inc',
#          'chipotle-mexican', 'visteon-corporation', 'hanesbrands', 'ge',
#          'safeway', 'kia', 'waste-management', 'tyson',
#          'avery-dennison-corporation', 'becton-dickinson-and-company',
#          'newmont-mining-corporation', 'merck', 'host-hotels-and-resorts',
#          'heinz', 'tiffany-co', 'ppl-corporation', 'esso', 'gatorade',
#          'family-dollar', 'cerner-corp', 'seaboard-corporation', 'carnival',
#          'mountain-dew', 'kraft', 'simon-property-group', 'tommy-hilfiger',
#          'stryker', 'aflac', 'tropicana-beverages', 'biogen-idec-inc',
#          'univar', 'espn', 'corning', 'parker-hannifin', 'williams', 'upc',
#          'bristol-myers-squibb', 'reynolds-american', 'land-olakes',
#          'motorola', 'sysco', 'bcg', 'hd-supply', 'neutrogena', 'linkedin',
#          'iheartmedia', 'tata-consultancy-services', 'cabelas-inc',
#          'american-electric-power-company', 'mobil', 'oshkosh-corporation',
#          'cadillac', 'tripadvisor', 'dr-pepper', 'monsanto-company',
#          'barnes-noble', 'cognizant', 'owens-corning', 'sheraton',
#          'domtar-corporation', 'loews-corporation', 'metlife',
#          'steel-dynamics', 'mondelez-international', 'apache',
#          'nextera-energy', 'mgm-resorts-international', 'priceline',
#          'performance-food-group-company', 'dover-corporation', 'hermes',
#          'cme', 'health-net-inc', 'delek-us-holdings',
#          'harman-international-industries', 'rackspace', 'ingram-micro',
#          'mercedes-benz', 'lear-corporation', 'conocophillips', 'emerson',
#          'quanta-services-inc', 'electronic-arts', 'exelon', 'kitchenaid',
#          'pitney-bowes-inc', 'teachers-insurance-and-annuity-association',
#          'huntington-ingalls-industries', 'iron-mountain-inc',
#          'holiday-inn', 'markel-corporation', 'snap-on-inc',
#          'hyatt-regency', 'fedex', 'p-and-g', 'bank-of-america', 'aramark',
#          'ch-robinson', 'seagate', 'flowers-foods', 'actavis',
#          'republic-services', 'commercial-metals-company',
#          'wec-energy-group', 'harley-davidson', 'timberland',
#          'under-armour', 'guardian-life-ins-co-of-america', 'moodys',
#          'subway', 'borgwarner-inc', 'hyundai', 'mtv', 'pacific-life',
#          'owens-minor', 'abm', 'tjx', 'norfolk', 'johnson-controls',
#          'ameren-corporation', 'bbt', 'salesforce',
#          'archerdanielsmidland-company', 'goodyear',
#          'american-financial-group', 'hp-enterprise', 'chevron',
#          'plains-gp-holdings', 'cablevision-systems-corporation',
#          'huntsman-corporation', 'darden-restaurants',
#          'ak-steel-holding-corporation', 'marathon-petroleum', 'accenture',
#          'parliament', 'skechers', 'us-foods-holding-corp', 'dr-horton',
#          'nisource', 'eli-lilly-and-company', 'jack-in-the-box', 'anadarko',
#          'johnsons', 'western-union', 'constellation-brands',
#          'molina-healthcare', 'tesoro-corporation', 'weyerhaeuser',
#          'allergan', 'cbre', 'marshalls', 'broadcom', 'grey-goose',
#          'gilead-sciences', 'harris-corp', 'black-and-decker', 'teradata',
#          'erie-insurance-group', 'marriott', 'csc', 'owensillinois', 'zara',
#          'reinsurance-group-of-america', 'volkswagen', 'facebook',
#          'autozone', 'philip-morris', 'estee-lauder', 'nvidia', 'devon',
#          'monster-beverage', 'ramada', 'adidas', 'dominos-pizza', 'sundown',
#          'newport', 'optumhealth', 'thrivent-financial-for-lutherans',
#          'new-york-life-insurance-company', 'american-airlines',
#          'american-family-insurance-group', 'heineken', 'lennar',
#          'southwest', 'calvin-klein', 'pultegroup', 'general-dynamics',
#          'folgers', 'bacardi', 'tech-data', 'quest-diagnostic',
#          'lam-research-corporation', 'chs',
#          'first-american-financial-corporation', 'tenneco',
#          'amerisourcebergen', 'arthur-j-gallagher--co', 'regions', 'wipro',
#          'burberry', 'bmw', 'abc', 'ball-corp', 'prada', 'blackrock',
#          'allianz', 'akamai-technologies', 'ecolab-inc', 'victorias-secret',
#          'samsung', 'morgan-stanley', 'united-technologies', 'vmware',
#          'cst-brands', 'treehouse-foods', 'chesterfield', 'clorox',
#          'max-factor', 'targa-resources-corp', 'bed-bath-and-beyond',
#          'arrow-electronics', 'avis-budget-group', 'citi', 'pbf-energy',
#          'jarden-corporation', 'ameriprise-financial', 'honeywell',
#          'gamestop', 'westin', 'western-refining', 'time-inc', 'tracfone',
#          'fastenal-co', 'camel', 'polaris-inds', 'national-oilwell-varco',
#          'blackstone', 'exxonmobil', 'raymond-james', 'las-vegas-sands',
#          'the-bank-of-new-york-mellon', 'nucor-corporation', 'dollar-tree',
#          'invesco', 'group-1-automotive', 'foot-locker', 'buick',
#          'sherwin-williams', 'qualcomm', 'sprite', 'wynn-resorts', 'intel',
#          'ebay', 'mcdonalds', 'energy-future-holdings-corp', 'yahoo',
#          'google', 'dollar-general', 'citizens', 'danaher', 'unitedhealth',
#          'nationwide-mutual-insurance-co', 'envision-healthcare-holdings',
#          'freeport-mcmoran', 'prudential', 'levis', 'aes', 'ciel',
#          'colgate', 'loreal', 'hca-holdings', 'ingredion-incorporated',
#          'energy-transfer-equity', 'csx', 'insight-enterprises', 'gillette',
#          'caseys-general', 'rockwell-automation', 'first-data-corp',
#          'fiserv-inc', 'audi', 'sandisk', 'yoplait',
#          'massachusetts-mutual-life-insurance-company', 'lm', 'hertz',
#          'ww-grainger-inc', 'wesco-international',
#          'rr-donnelley-and-sons-co', 'courtyard', 'washington-post',
#          'aetna', 'ally-financial', 'discover', 'the-home-depot', 'target',
#          'amphenol-corporation', 'sams-club', 'royal-caribbean-cruises',
#          'asbury-automotive-group', 'johnnie-walker', 'jm-smucker',
#          'graybar-electric-company', 'amazon', 'ashland', 'veritiv-corp',
#          'phillips', 'mccormick', 'alaska-air-group', 'dillards',
#          'altria-group', 'cbi', 'alcoa', 'advance-auto-parts', 'apple',
#          'publix', 'enterprise', 'airbnb', 'realogy-holdings-corp',
#          'old-navy', 'cdw-corporation', 'ace', 'air-products--chemicals',
#          'liberty-mutual-holding-company', 'amgen', 'lifepoint-health',
#          'lee', 'lilly', 'stanley-black--decker', 'paypal',
#          'american-express', 'calpine-corporation', 'toys-r-us',
#          'tenet-healthcare-corp', 'doritos-tortilla-chips',
#          'precision-castparts-corp', 'youtube', 'landrover',
#          'boston-scientific-corp', 'supervalu', 'hersheys', 'airgas',
#          'ulta-salon-cosmetics', 'coca-cola', 'disney', 'progressive',
#          'cbs', 'spirit-aerosystems-holdings', 'nielsen', 'moet', 'twitter',
#          'oreilly-auto-parts', 'applied-materials', 'gucci',
#          'kimberlyclark-corporation', 'starbucks', 'united',
#          'ross-dress-for-less', 'autonation', 'the-hartford',
#          'l3-communications-holdings', 'centurylink', 'centerpoint-energy',
#          'essendant', 'symantec', 'adp', 'news-corporation', 'sun-america',
#          'carrier', 'thomson-reuters', 'assurant', 'dominion', 'xfinity',
#          'fanta', 'avon', 'sonic-automotive', 'agco-corporation',
#          'best-buy', 'the-north-face', 'nike', 'porsche', 'adobe',
#          'raytheon', 'murphy-usa', 'florida-power-and-light', 'emc2',
#          'texas-instruments', 'lyondellbasell', 'live-nation-entertainment'],
#         dtype=object),
#   'bp': array(['verizon', 'constellation-brands', 'time-inc', 'united', 'maytag',
#          'nestle', 'activision-blizzard', 'cbs', 'polaris-inds',
#          'eli-lilly-and-company', 'american-airlines', 'gmc',
#          'borgwarner-inc', 'sabre', 'envision-healthcare-holdings',
#          'liberty-interactive-corporation', 'office-depot',
#          'quintiles-transnational-holdings', 'republic-services',
#          'tracfone', 'twitter', 'phillips', 'johnson-johnson',
#          'lawson-software', 'minute-maid', 'sysco', 'enterprise',
#          'sanmina-corporation', 'upc', 'facebook', 'cvs', 'ebay', 'oneok',
#          'fannie-mae', 'xbox', 'cartier', 'walgreens', 'lego',
#          'harris-corp', 'spirit-aerosystems-holdings', 'jm-smucker',
#          'entergy', 'mgm-resorts-international', 'qualcomm', 'nisource',
#          'alaska-air-group', 'petsmart', 'gucci', 'westin', 'eog-resources',
#          'edison-international', 'optumhealth', 'lilly',
#          'realogy-holdings-corp', 'altria-group', 'devon',
#          'rite-aid-corporation', 'tommy-hilfiger', 'csc',
#          'domtar-corporation', 'exelon', 'national-oilwell-varco',
#          'hersheys', 'plains-gp-holdings', 'asbury-automotive-group',
#          'wynn-resorts', 'jb-hunt-transport-services', 'toys-r-us',
#          'cablevision-systems-corporation', 'harman-intl',
#          'henry-schein-inc', 'darden-restaurants', 'sirius',
#          'bed-bath-and-beyond', 'medtronic', 'paypal', 'travelers',
#          'ingersoll-rand', 'reinsurance-group-of-america', 'fedex',
#          'stanley-black--decker', 'dollar-tree', 'trinity-industries',
#          'tropicana-beverages', 'parker-hannifin', 'baxter-international',
#          'wesco-international', 'pge', 'mastercard',
#          'jones-lang-lasalle-incorporated', 'agco-corporation',
#          'thermo-fisher-scientific', 'dior', 'colgate', 'csx', 'blackrock',
#          'reliance-steel-aluminum-co', 'pedigree', 'omnicom-group',
#          'jp-morgan', 'kelloggs', 'spectrum', 'celgene',
#          'insight-enterprises', 'schlumberger',
#          'l3-communications-holdings', 'tesoro-corporation',
#          'international-paper', 'charter-communications', 'tiffany-co',
#          'whirlpool', 'akamai-technologies', 'cms-energy-corporation',
#          'fanta', 'qvc', 'hyatt', 'lithia-motors',
#          'tata-consultancy-services', 'raymond-james', 'conocophillips',
#          'canon', 'hyatt-regency', 'penske-automotive-group', 'xerox',
#          'honda', 'caterpillar', 'airbnb', 'coca-cola', 'mckinsey', 'apple',
#          'eaton', 'state-street', 'honeywell',
#          'cincinnati-financial-corporation', 'subway', 'waste-management',
#          'motorola', 'crown-holdings-inc', 'avis-budget-group',
#          'aecom-technology', 'ncr-corporation', '21st-century-fox',
#          'ch-robinson', 'courtyard', 'nissan', 'targa-resources-corp',
#          'allergan', 'allstate', 'nvr', 'ameren-corporation', 'ikea',
#          'welltower-inc', 'dollar-general', 'hp-enterprise', 'sony',
#          'expedia', 'deloitte', 'western-digital', 'ppg', 'levis',
#          'applied-materials', 'washington-post', 'fifth-third-bank', 'mars',
#          'ross-dress-for-less', 'cintas-corp', 'eversource-energy',
#          'principal-financial-group', 'assurant', 'salesforce', 'gatorade',
#          'molina-healthcare', 'hd-supply', 'mountain-dew', 'nike',
# ...
#          'itw', 'chesapeake-energy-corporation', 'merck', 'hyatt',
#          'deere--company', 'youtube', 'cdw-corporation', 'biogen-idec-inc',
#          'visteon-corporation', 'energy-transfer-equity',
#          '21st-century-fox', 'uber', 'steel-dynamics', 'trinity-industries',
#          'bnsf-railway', 'dr-horton', 'maytag', 'danone', 'pultegroup',
#          'sanmina-corporation', 'first-american-financial-corporation',
#          'ngl-energy-partners-lp', 'oral-b', 'arrow-electronics',
#          'polaris-inds', 'newell-brands', 'mobil',
#          'harman-international-industries', 'mckesson', 'avis-budget-group',
#          'yum-brands', 'huntington-ingalls-industries', 'family-dollar',
#          'world-fuel-services-corporation', 'bond-street', 'cartier',
#          'audi', 'stanley-black--decker', 'prada',
#          'newmont-mining-corporation', 'whole-foods',
#          'anixter-international', 'costco', 'skechers',
#          'philadelphia-insurance-companies', 'netflix', 'zara',
#          'synnex-corporation', 'kimberlyclark-corporation',
#          'commercial-metals-company', 'carrier', 'gilead-sciences', 'fedex',
#          'boeing', 'salesforce', 'crown-holdings-inc',
#          'autoowners-insurance-group', 'wynn-resorts', 'csx', 'johnsons',
#          'eversource-energy', 'tech-data', 'penske-automotive-group',
#          'mercedes-benz', 'blackstone', 'thermo-fisher-scientific',
#          'spartannash-company', 'ball-corp', 'marathon-petroleum',
#          'facebook', 'autonation', 'nike', 'markel-corporation', 'michaels',
#          'eastman-chemical-company', 'booking', 'hanesbrands',
#          'spirit-aerosystems-holdings', 'ppl-corporation', 'prudential',
#          'live-nation-entertainment', 'jm-smucker', 'mckinsey', 'walmart',
#          'allstate', 'cms-energy-corporation', 'nvr', 'conocophillips',
#          'harman-intl', 'phillips', 'american-family-insurance-group',
#          'seagate', 'jabil', 'carmax', 'xfinity', 'chubb',
#          'leucadia-national-corporation', 'cbi', 'qvc', 'news-corporation',
#          'baxalta-incorporated', 'purina', 'exelon', 'chevron', 'bacardi',
#          'ameriprise-financial', 'kfc', 'mgm-resorts-international',
#          'alaska-air-group', 'petsmart', 'cincinnati-financial-corporation',
#          'united', 'nissan', 'lkq-corporation', 'mohawk-industries',
#          'dr-pepper', 'emc-corporation', 'jack-in-the-box', 'dominos-pizza',
#          'owens-minor', 'neutrogena', 'courtyard',
#          'travelcenters-of-america-llc', 'precision-castparts-corp'],
#         dtype=object),
#   'full2': array(['celgene', 'paramount', 'ch-robinson', 'united-technologies',
#          'veritiv-corp', 'costco', 'nisource', 'hilton', 'ups',
#          'cardinal-health', 'hanesbrands', 'western-refining',
#          'the-hartford', 'rockwell-automation', 'huntsman-corporation',
#          'neutrogena', 'mondelez-international', 'nvr', 'kfc', 'paccar-inc',
#          'sempra-energy', 'kelly-services', 'borgwarner-inc', 'abm',
#          'univar', 'sundown', 'weyerhaeuser', 'dean-foods-company',
#          'cerner-corp', 'allergan', 'baker-hughes', 'masco',
#          'the-north-face', 'walmart', 'carmax', 'cme', 'trinity-industries',
#          'best-buy', 'cognizant', 'tenneco', 'sun-america', 'courtyard',
#          'citi', 'goodyear', 'infosys', 'hyatt', 'yoplait',
#          'freeport-mcmoran', 'equinix', 'principal-financial-group',
#          'tripadvisor', 'optumhealth', 'john-hancock', 'pratt-and-whitney',
#          'fanta', 'doritos-tortilla-chips', 'pge', 'apache', 'pseg',
#          'flowers-foods', 'health-net-inc', 'alaska-air-group',
#          'quest-diagnostic', 'harris-corp', 'lilly', 'arrow-electronics',
#          'abc', 'dr-horton', 'alphabet', 'molina-healthcare', 'snap-on-inc',
#          'merck', 'cbs', 'coors', 'bristol-myers-squibb', 'geico',
#          'timberland', 'vmware', 'barnes-noble', 'ciel',
#          'crown-holdings-inc', 'firstenergy-corp', 'estee-lauder',
#          'panera-bread', 'iheartmedia', 'visteon-corporation', 'sabre',
#          'gucci', 'pbf-energy', 'jack-in-the-box', 'applied-materials',
#          'comcast-corporation', 'twitter', 'csx', 'aramark',
#          'chipotle-mexican', 'cadillac', 'first-data-corp', 'spectrum',
#          'baxalta-incorporated', 'conocophillips', 'fossil',
#          'dish-networks', 'mini', 'hca-holdings', 'johnnie-walker',
#          'fmc-technologies', 'farmers-insurance-exchange', 'porsche',
#          'international-paper', 'walgreens', 'heineken', 'gilead-sciences',
#          'entergy', 'vf-corporation', 'energy-future-holdings-corp',
#          'jones-lang-lasalle-incorporated',
#          'starwood-hotels--resorts-worldwide', 'wipro', 'tech-data', 'esso',
#          'cvs', 'medtronic', 'royal-caribbean-cruises', 'ford',
#          'schlumberger', 'ugi-corporation',
#          'mutual-of-omaha-insurance-company', 'general-dynamics', 'cummins',
#          'honeywell', 'norwegian-cruise', 'jp-morgan',
#          'sealed-air-corporation', 'lifepoint-health', 'calvin-klein',
#          'loreal', 'penske-automotive-group', 'tech-mahindra', 'exelon',
#          'centurylink', 'treehouse-foods', 'franklin-templeton-investments',
#          'wrigleys', 'eog-resources', 'google', 'marshalls', 'foot-locker',
#          'marathon-petroleum', 'stanley-black--decker', 'parliament',
#          'harman-intl', 'ameren-corporation', 'williams', 'qualcomm',
#          'kimberlyclark-corporation', 'dominos-pizza', 'office-depot',
#          'cisco', 'wells-fargo', 'csc', 'nationwide-mutual-insurance-co',
#          'michaels', 'tenet-healthcare-corp', 'philip-morris', 'qvc',
#          'washington-post', 'stryker', 'broadcom', 'michael-kors', 'gap',
#          'hertz', 'arthur-j-gallagher--co', 'bed-bath-and-beyond',
#          'emcor-group', 'abbott-labs', 'synnex-corporation', 'gillette',
#          'chevrolet', 'the-bank-of-new-york-mellon', 'bacardi',
#          'domtar-corporation', 'textron', 'mt-bank', 'oshkosh-corporation',
#          '21st-century-fox', 'salesforce', 'amphenol-corporation',
#          'enterprise', 'motorola', 'general-mills', 'us-bank', 'nordstrom',
#          'fluor', 'autoowners-insurance-group', 'cigna', 'kelloggs',
#          'ramada', 'rite-aid-corporation', 'american-express',
#          'group-1-automotive', 'ally-financial', 'coach',
#          'cincinnati-financial-corporation', 'sony', 'cbi', 'oral-b',
#          'tyson', 'quanta-services-inc', 'fidelity-national',
#          'archerdanielsmidland-company', 'grey-goose', 'target', 'xerox',
#          'expeditors-international-of-washington', 'caseys-general',
#          'johnsons', 'hyatt-regency', 'verizon', 'amazon',
#          'ppl-corporation', 'louis-vuitton', 'agco-corporation',
#          'air-products--chemicals', 'kia', 'amerisourcebergen',
#          'tropicana-beverages', 'erie-insurance-group', 'sysco', 'folgers',
#          'fastenal-co', 'sanmina-corporation', 'spartannash-company',
#          'sherwin-williams', 'omnicom-group', 'xbox', 'lithia-motors',
#          'garmin', 'l-brands', 'philadelphia-insurance-companies',
#          'performance-food-group-company', 'blackrock',
#          'peabody-energy-corporation', 'whole-foods',
#          'newmont-mining-corporation', 'thrivent-financial-for-lutherans',
#          'packaging-corporation-of-america', 'cartier', 'xpo-logistics',
#          'fedex', 'halliburton', 'terex-corporation',
#          'national-oilwell-varco', 'hersheys', 'plains-gp-holdings',
#          'lkq-corporation', 'nissan', 'sprite', 'ppg',
#          'quaker-foods-and-snacks', 'big-lots', 'rackspace', 'mastercard',
#          'nvidia', 'darden-restaurants', 'state-farm-insurance-cos',
#          'unum-group', 'volkswagen', 'baxter-international',
#          'universal-music-group', 'valero', 'sams-club',
#          'tesoro-corporation', 'cst-brands', 'pultegroup', 'hm', 'bcg',
#          'ace', 'nestle', 'jabil', 'state-street', 'autoliv', 'sheraton',
#          'spectra-energy-corp', 'ameriprise-financial', 'hormel',
#          'cons-edison-inc', 'ch2m-hill-companies',
#          'spirit-aerosystems-holdings', 'laboratory-corp-of-america',
#          'dte-energy-co', 'clinique', 'cms-energy-corporation', 'mckesson',
#          'bnsf-railway', 'northwestern-mutual-life-insurance-company',
#          'lansing-trade-group', 'conagra-foods', 'facebook', 'hsbc',
#          'oneok', 'wesco-international', 'host-hotels-and-resorts', 'honda',
#          'invesco', 'lee', 'mars', 'ingram-micro', 'wynn-resorts',
#          'st-jude-medical', 'booking', 'suntrust',
#          'american-family-insurance-group', 'anthem', 'duke-energy',
#          'tesla', 'hp-enterprise', 'staples', 'owensillinois',
#          'targa-resources-corp', 'florida-power-and-light', 'teradata',
#          'owens-corning', 'illinois-tool-works', 'caterpillar',
#          'mgm-resorts-international', 'cabelas-inc',
#          'energy-transfer-equity', 'mountain-dew', 'aecom-technology',
#          'netflix', 'dior', 'pacific-life', 'bond-street', 'camel',
#          'dicks-sporting', 'voya-financial', 'marriott', 'dillards', 'avon',
#          'subway', 'macys', 'burlington-stores', 'discovery-media',
#          'news-corporation', 'mckinsey', 'upc', 'mccormick',
#          'reliance-steel-aluminum-co', 'du-pont',
#          'sears-holdings-corporation', 'emc-corporation', 'amgen',
#          'akamai-technologies', 'eaton', 'metlife', 'eli-lilly-and-company',
#          'mclane-company', 'lockheed-martin', 'lowes', 'gamestop', 'nike',
#          'united', 'santander', 'aes', 'envision-healthcare-holdings',
#          'dollar-general', 'ibm', 'oreilly-auto-parts', 'wyndham',
#          'chesterfield', 'biogen-idec-inc', 'lm', 'gatorade',
#          'union-pacific', 'tommy-hilfiger', 'mac', 'reynolds-american',
#          'goldman-sachs', 'hollyfrontier-corporation', 'american-airlines',
#          'ross-dress-for-less', 'texas-instruments',
#          'dana-holding-corporation', 'intel', 'gmc', 'espn',
#          'welltower-inc', 'huntington-ingalls-industries',
#          'simon-property-group', 'freddie-mac', 'mattel', 'exxonmobil',
#          'victorias-secret', 'landrover', 'black-and-decker', 'hyundai',
#          'sandisk', 'ikea', 'autonation', 'workday', 'adp', 'devon',
#          'microsoft', 'avery-dennison-corporation',
#          'old-republic-international-corporation', 'tjx', 'food-4-less',
#          'travelers', 'moodys', 'lincoln', 'kohls',
#          'liberty-interactive-corporation', 'sap', 'hbo', 'cadbury',
#          'calpine-corporation', 'assurant', 'blackstone',
#          'southern-company', 'time-inc', 'delek-us-holdings', 'cbre',
#          'moet', 'progressive', 'global-partners-lp', 'deere--company',
#          'avnet', 'audi', 'supervalu', 'cdw-corporation', 'essendant',
#          'loews-corporation', 'carrier', 'panasonic', 'chase', 'zimmer',
#          'clorox', 'apple', 'patterson-companies', 'tractor-supply',
#          'graybar-electric-company', 'allianz', 'polaris-inds',
#          'harman-international-industries', 'us-foods-holding-corp',
#          'kinder-morgan', 'henry-schein-inc', 'delta', 'lennar',
#          'dr-pepper', 'pizza-hut', 'charter-communications', 'fiserv-inc',
#          'harley-davidson', 'danaher', 'sonic-automotive',
#          'universal-health-services', 'nbc',
#          'teachers-insurance-and-annuity-association',
#          'insight-enterprises', 'p-and-g', 'xcel-energy-inc',
#          'first-american-financial-corporation',
#          'leucadia-national-corporation', 'hrg-group', 'westin', 'pvh-corp',
#          'taco-bell', 'emc2', 'navient-corporation', 'kenworth', 'fox',
#          'liberty-mutual-holding-company', 'fifth-third-bank', 'ball-corp',
#          'live-nation-entertainment', 'kkr', 'xfinity', 'micron-technology',
#          'electronic-arts', 'aetna', 'tiffany-co', 'mobil',
#          'jarden-corporation', 'publix', 'norfolk',
#          'world-fuel-services-corporation', 'canon', 'starbucks',
#          'old-navy', 'paypal', 'autozone', 'priceline', 'buick',
#          'commercial-metals-company', 'dhl', 'johnson-johnson', 'youtube',
#          'edison-international', 'boeing', 'windstream', 'petsmart',
#          'adidas', 'hess', 'ebay', 'ingersoll-rand', 'adobe', 'toys-r-us',
#          'chesapeake-energy-corporation', 'anixter-international', 'dell',
#          'waste-management', 'airbnb', 'kindred-healthcare', 'sirius',
#          'ncr-corporation', 'max-factor', 'whirlpool', 'phillips',
#          'fannie-mae', 'accenture', 'jacobs-engineering',
#          'nucor-corporation', 'lear-corporation',
#          'community-health-systems', 'guardian-life-ins-co-of-america',
#          'lam-research-corporation', 'ge', 'constellation-brands', 'uber',
#          'under-armour', 'praxair', 'tracfone', 'kraft', 'ww-grainger-inc',
#          'coca-cola', 'nrg-energy', 'dominion', 'purina', 'level-3',
#          'coremark-holding-company',
#          'massachusetts-mutual-life-insurance-company', 'burberry',
#          'telephone-and-data-systems', 'pitney-bowes-inc', 'jm-smucker',
#          'pedigree', 'dollar-tree', 'precision-castparts-corp',
#          'johnson-controls', 'ingredion-incorporated',
#          'booz-allen-hamilton-holding-corp', 'express-scripts',
#          'mercedes-benz', 'nextera-energy', 'airgas', 'family-dollar',
#          'linkedin', 'aig', 'tata-consultancy-services',
#          'boston-scientific-corp', 'intl-fcstone', 'monsanto-company',
#          'expedia', 'deloitte', 'land-olakes', 'general-motors', 'safeway',
#          'avis-budget-group', 'newell-brands', 'las-vegas-sands', 'nielsen',
#          'levis', 'monster-beverage', 'humana-inc', 'warner-bros',
#          'wec-energy-group', 'campbells', 'ralph-lauren',
#          'advance-auto-parts', 'cinemark', 'eversource-energy', 'seagate',
#          'ashland', 'republic-services', 'capital-one', 'dover-corporation',
#          'colgate', 'steel-dynamics', 'dow', 'reinsurance-group-of-america',
#          'centene-corporation', 'visa', 'sunoco', 'prada',
#          'markel-corporation', 'disney', 'raymond-james', 'parker-hannifin',
#          'hermes', 'lyondellbasell', 'cintas-corp', 'actavis', 'aflac',
#          'mohawk-industries', 'eastman-chemical-company',
#          'jetblue-airways-corporation', 'quintiles-transnational-holdings',
#          'chubb', 'att', 'pnc', 'ulta-salon-cosmetics', 'pfizer',
#          'minute-maid', 'alliance-data-systems-corp', 'seiyu',
#          'occidental-petroleum-corporation', 'unitedhealth',
#          'travelcenters-of-america-llc', 'l3-communications-holdings',
#          'the-home-depot', 'becton-dickinson-and-company', 'frontier',
#          'owens-minor', 'raytheon', 'corning', 'citizens', 'symantec',
#          'centerpoint-energy', 'celanese-corporation',
#          'thermo-fisher-scientific', 'kitchenaid', 'newport', 'burger-king',
#          'mcdonalds', 'lenovo', 'hcl-technologies', 'davita-healthcar',
#          'lawson-software', '3m', 'discover', 'bank-of-america',
#          'ngl-energy-partners-lp', 'charles-schwab', 'seaboard-corporation',
#          'carnival', 'hd-supply', 'heinz', 'regions', 'directv', 'alcoa',
#          'zara', 'wellcare-health-plans', 'otis', 'doubletree', 'southwest',
#          'lego', 'westrock-company', 'hp', 'pepsi',
#          'jb-hunt-transport-services', 'asbury-automotive-group', 'toyota',
#          'realogy-holdings-corp', 'altria-group', 'morgan-stanley',
#          'anadarko', 'maytag', 'ryder-system', 'yum-brands', 'budweiser',
#          'samsung', 'mtv', 'emerson', 'activision-blizzard', 'holiday-inn',
#          'allstate', 'thomson-reuters', 'itw', 'kroger',
#          'american-electric-power-company', 'american-financial-group',
#          'western-digital', 'netapp', 'rr-donnelley-and-sons-co',
#          'jc-penney', 'danone', 'cablevision-systems-corporation', 'bmw',
#          'skechers', 'murphy-usa', 'yahoo',
#          'cameron-international-corporation', 'chevron', 'chs',
#          'ecolab-inc', 'siemens', 'mosaic', 'prudential', 'western-union',
#          'bbt', 'new-york-life-insurance-company',
#          'ak-steel-holding-corporation', 'iron-mountain-inc', 'abbvie-inc'],
#         dtype=object)}}
